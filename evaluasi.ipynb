# %%
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/suxeno/StudyDateAI-Week1-Evaluation-Dataset/refs/heads/main/portugal-housing-sample.csv"

# %%
df = pd.read_csv(url)
df.head()
# Out:
#       Price District                 City  \
# 0   55000.0  Coimbra      Figueira da Foz
# 1  289000.0  Setúbal              Montijo
# 2   46500.0   Lisboa             Lourinhã
# 3  203000.0    Porto    Vila Nova de Gaia
# 4   72500.0    Braga  Cabeceiras de Basto
#
#                                    Town       Type EnergyCertificate  \
# 0                             Alqueidão       Land                NC
# 1                                 Canha      House                 D
# 2                    Lourinhã e Atalaia       Land                NC
# 3                    Vilar de Andorinho  Apartment                 E
# 4  Refojos de Basto, Outeiro e Painzela       Land                NC
#
#        Floor   Lift  Parking HasParking  ...  Elevator  ElectricCarsCharging  \
# 0        NaN  False      0.0      False  ...       NaN                   NaN
# 1        NaN  False      2.0       True  ...       NaN                   NaN
# ...

# %%
#cek dimensi dataset
df.shape
# Out:
# (20000, 25)

# %%
#cek nama kolom dalam dataset
df.columns
# Out:
# Index(['Price', 'District', 'City', 'Town', 'Type', 'EnergyCertificate',
#        'Floor', 'Lift', 'Parking', 'HasParking', 'ConstructionYear',
#        'TotalArea', 'GrossArea', 'PublishDate', 'Garage', 'Elevator',
#        'ElectricCarsCharging', 'TotalRooms', 'NumberOfBedrooms', 'NumberOfWC',
#        'ConservationStatus', 'LivingArea', 'LotSize', 'BuiltArea',
#        'NumberOfBathrooms'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Price                 20000 non-null  float64
#  1   District              20000 non-null  object
#  2   City                  20000 non-null  object
#  3   Town                  19999 non-null  object
#  4   Type                  20000 non-null  object
#  5   EnergyCertificate     20000 non-null  object
#  6   Floor                 4925 non-null   object
#  7   Lift                  11874 non-null  object
#  8   Parking               19967 non-null  float64
#  9   HasParking            11874 non-null  object
#  10  ConstructionYear      12965 non-null  float64
#  11  TotalArea             18941 non-null  float64
#  12  GrossArea             4790 non-null   float64
#  13  PublishDate           2668 non-null   object
# ...

# %%
df.nunique()
# Out:
# Price                   2130
# District                  24
# City                     264
# Town                    1869
# Type                      21
# EnergyCertificate         11
# Floor                     18
# Lift                       2
# Parking                    4
# HasParking                 2
# ConstructionYear         114
# TotalArea               3035
# GrossArea                947
# PublishDate             2656
# Garage                     2
# Elevator                   2
# ElectricCarsCharging       2
# TotalRooms                33
# NumberOfBedrooms          20
# NumberOfWC                14
# ConservationStatus         6
# LivingArea              1464
# LotSize                 2250
# BuiltArea               1728
# NumberOfBathrooms         27
# dtype: int64

# %%
df.isna().sum()
# Out:
# Price                       0
# District                    0
# City                        0
# Town                        1
# Type                        0
# EnergyCertificate           0
# Floor                   15075
# Lift                     8126
# Parking                    33
# HasParking               8126
# ConstructionYear         7035
# TotalArea                1059
# GrossArea               15210
# PublishDate             17332
# Garage                  11877
# Elevator                11877
# ElectricCarsCharging    11877
# TotalRooms               8564
# NumberOfBedrooms        14636
# NumberOfWC              12695
# ConservationStatus      17673
# LivingArea               4690
# LotSize                 14944
# BuiltArea               16737
# NumberOfBathrooms         877
# dtype: int64

# %%
df[df['Parking'].isna()]
# Out:
#            Price          District                  City  \
# 213      35000.0           Coimbra       Figueira da Foz
# 456     215000.0            Aveiro  Santa Maria da Feira
# 1899    299900.0             Porto     Vila Nova de Gaia
# 2461    575000.0             Braga                 Braga
# 2824    459500.0          Santarém               Coruche
# 4099     17500.0              Faro                Silves
# 4650     80000.0             Porto           Santo Tirso
# 5261     42000.0    Castelo Branco              Belmonte
# 5547   1700000.0            Lisboa         Torres Vedras
# 5723    195000.0         Vila Real                Chaves
# 5963    455000.0             Braga                 Braga
# 7601    539000.0    Castelo Branco               Covilhã
# 7668    455000.0             Braga                 Braga
# 8933     91200.0             Porto               Lousada
# 9608    319000.0           Coimbra               Coimbra
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['District'] = encoder.fit_transform(df['District'])
df['City'] = encoder.fit_transform(df['City'])
df['Town'] = encoder.fit_transform(df['Town'])
df['Type'] = encoder.fit_transform(df['Type'])
df['EnergyCertificate'] = encoder.fit_transform(df['EnergyCertificate'])
df['Floor'] = encoder.fit_transform(df['Floor'])
df['Lift'] = encoder.fit_transform(df['Lift'])
df['HasParking'] = encoder.fit_transform(df['HasParking'])
df['PublishDate'] = encoder.fit_transform(df['PublishDate'])
df['Garage'] = encoder.fit_transform(df['Garage'])
df['Elevator'] = encoder.fit_transform(df['Elevator'])
df['ElectricCarsCharging'] = encoder.fit_transform(df['ElectricCarsCharging'])
df['ConservationStatus'] = encoder.fit_transform(df['ConservationStatus'])

# %%
data_copy = df.copy (deep=True)
mean_floor = data_copy['Floor'].mean()
mean_lift = data_copy['Lift'].mean()
mean_parking = data_copy['Parking'].mean()
mean_has_parking = data_copy['HasParking'].mean()
mean_construction_year = data_copy['ConstructionYear'].mean()
mean_total_area = data_copy['TotalArea'].mean()
mean_gross_area = data_copy['GrossArea'].mean()
mean_garage = data_copy['Garage'].mean()
mean_elevator = data_copy['Elevator'].mean()
mean_electric_cars_charging = data_copy['ElectricCarsCharging'].mean()
mean_total_rooms = data_copy['TotalRooms'].mean()
mean_number_of_bedrooms = data_copy['NumberOfBedrooms'].mean()
mean_number_of_wc = data_copy['NumberOfWC'].mean()
mean_conservation_status = data_copy['ConservationStatus'].mean()
mean_living_area = data_copy['LivingArea'].mean()
mean_lot_size = data_copy['LotSize'].mean()
mean_built_area = data_copy['BuiltArea'].mean()
mean_number_of_bathrooms = data_copy['NumberOfBathrooms'].mean()

# %%
print(f"Mean of Floor               : {mean_floor}")
print(f"Mean of Lift                : {mean_lift}")
print(f"Mean of Parking             : {mean_parking}")
print(f"Mean of HasParking          : {mean_has_parking}")
print(f"Mean of ConstructionYear    : {mean_construction_year}")
print(f"Mean of TotalArea           : {mean_total_area}")
print(f"Mean of GrossArea           : {mean_gross_area}")
print(f"Mean of Garage              : {mean_garage}")
print(f"Mean of Elevator             : {mean_elevator}")
print(f"Mean of ElectricCarsCharging : {mean_electric_cars_charging}")
print(f"Mean of TotalRooms          : {mean_total_rooms}")
print(f"Mean of NumberOfBedrooms    : {mean_number_of_bedrooms}")
print(f"Mean of NumberOfWC          : {mean_number_of_wc}")
print(f"Mean of ConservationStatus  : {mean_conservation_status}")
print(f"Mean of LivingArea          : {mean_living_area}")
print(f"Mean of LotSize             : {mean_lot_size}")
print(f"Mean of BuiltArea           : {mean_built_area}")
print(f"Mean of NumberOfBathrooms   : {mean_number_of_bathrooms}")
# Out:
# Mean of Floor               : 14.86745
# Mean of Lift                : 0.9632
# Mean of Parking             : 0.5805078379325888
# Mean of HasParking          : 1.0806
# Mean of ConstructionYear    : 1988.7430003856537
# Mean of TotalArea           : 21475.36956866058
# Mean of GrossArea           : 2112.3146137787057
# Mean of Garage              : 1.25955
# Mean of Elevator             : 1.2797
# Mean of ElectricCarsCharging : 1.2261
# Mean of TotalRooms          : 3.2917978314095837
# Mean of NumberOfBedrooms    : 2.691461595824012
# Mean of NumberOfWC          : 0.3967145790554415
# Mean of ConservationStatus  : 5.54875
# Mean of LivingArea          : 2000.3846505551926
# Mean of LotSize             : 15299.29628164557
# Mean of BuiltArea           : 7416.584757891511
# Mean of NumberOfBathrooms   : 1.5082361554149453

# %%
data_copy.fillna({
    'Floor': mean_floor,
    'Lift': mean_lift,
    'Parking': mean_parking,
    'HasParking': mean_has_parking,
    'ConstructionYear': mean_construction_year,
    'TotalArea': mean_total_area,
    'GrossArea': mean_gross_area,
    'Garage': mean_garage,
    'Elevator': mean_elevator,
    'ElectricCarsCharging': mean_electric_cars_charging,
    'TotalRooms': mean_total_rooms,
    'NumberOfBedrooms': mean_number_of_bedrooms,
    'NumberOfWC': mean_number_of_wc,
    'ConservationStatus': mean_conservation_status,
    'LivingArea': mean_living_area,
    'LotSize': mean_lot_size,
    'BuiltArea': mean_built_area,
    'NumberOfBathrooms': mean_number_of_bathrooms
}, inplace=True)

# %%
df[df['Parking'].isna()]
# Out:
#            Price  District  City  Town  Type  EnergyCertificate  Floor  Lift  \
# 213      35000.0         5    89   887     7                  9     18     0
# 456     215000.0         0   198  1405     7                  5     18     0
# 1899    299900.0        16   245  1157     7                  6     18     0
# 2461    575000.0         2    49   477     7                  0     18     0
# 2824    459500.0        17    74   296     7                  9     18     0
# 4099     17500.0         6   211    81    10                  9     18     0
# 4650     80000.0        16   202  1280     7                  9     18     0
# 5261     42000.0         4    44   277    10                  9     18     0
# 5547   1700000.0        14   225  1603     7                  2     18     0
# 5723    195000.0        20    70  1402    17                  7     18     0
# 5963    455000.0         2    49  1118     7                  3     18     0
# ...

# %%
data_copy.isna().sum()
# Out:
# Price                   0
# District                0
# City                    0
# Town                    0
# Type                    0
# EnergyCertificate       0
# Floor                   0
# Lift                    0
# Parking                 0
# HasParking              0
# ConstructionYear        0
# TotalArea               0
# GrossArea               0
# PublishDate             0
# Garage                  0
# Elevator                0
# ElectricCarsCharging    0
# TotalRooms              0
# NumberOfBedrooms        0
# NumberOfWC              0
# ConservationStatus      0
# LivingArea              0
# LotSize                 0
# BuiltArea               0
# NumberOfBathrooms       0
# dtype: int64

# %%
from sklearn.impute import KNNImputer
null_column = [
    'Town', 'Floor', 'Lift', 'Parking', 'HasParking',
    'ConstructionYear', 'TotalArea', 'GrossArea', 'PublishDate',
    'Garage', 'Elevator', 'ElectricCarsCharging', 'TotalRooms',
    'NumberOfBedrooms', 'NumberOfWC', 'ConservationStatus',
    'LivingArea', 'LotSize', 'BuiltArea', 'NumberOfBathrooms'
]
imputer = KNNImputer(n_neighbors=5)
df[null_column] = imputer.fit_transform(df[null_column])

# %%
df.isna().sum()
# Out:
# Price                   0
# District                0
# City                    0
# Town                    0
# Type                    0
# EnergyCertificate       0
# Floor                   0
# Lift                    0
# Parking                 0
# HasParking              0
# ConstructionYear        0
# TotalArea               0
# GrossArea               0
# PublishDate             0
# Garage                  0
# Elevator                0
# ElectricCarsCharging    0
# TotalRooms              0
# NumberOfBedrooms        0
# NumberOfWC              0
# ConservationStatus      0
# LivingArea              0
# LotSize                 0
# BuiltArea               0
# NumberOfBathrooms       0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#           Price  District  City    Town  Type  EnergyCertificate  Floor  Lift  \
# 1412   885000.0        14   152  1226.0     7                  0   18.0   2.0
# 1569   340000.0         2    25   652.0     0                  9    3.0   1.0
# 2160   295000.0        14    10    72.0     7                  5   18.0   0.0
# 2296    27500.0        14    10  1744.0    10                  9   18.0   0.0
# 2298   400680.0        16   122   918.0     0                  0   18.0   2.0
# ...         ...       ...   ...     ...   ...                ...    ...   ...
# 19812  515000.0        16    86   900.0     7                  2   14.0   0.0
# 19860  120000.0        17    45   282.0    10                  9   18.0   2.0
# 19924  175000.0        16   182   303.0    18                  9   18.0   2.0
# 19951  165000.0        16   182   303.0    18                  9    0.0   1.0
# 19979   88000.0        13   263  1408.0     7                  9   18.0   0.0
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Price, District, City, Town, Type, EnergyCertificate, Floor, Lift, Parking, HasParking, ConstructionYear, TotalArea, GrossArea, PublishDate, Garage, Elevator, ElectricCarsCharging, TotalRooms, NumberOfBedrooms, NumberOfWC, ConservationStatus, LivingArea, LotSize, BuiltArea, NumberOfBathrooms]
# Index: []
#
# [0 rows x 25 columns]

# %%
data_numerik = df.select_dtypes(include=['int64', 'float'])
data_numerik.columns
# Out:
# Index(['Price', 'District', 'City', 'Town', 'Type', 'EnergyCertificate',
#        'Floor', 'Lift', 'Parking', 'HasParking', 'ConstructionYear',
#        'TotalArea', 'GrossArea', 'PublishDate', 'Garage', 'Elevator',
#        'ElectricCarsCharging', 'TotalRooms', 'NumberOfBedrooms', 'NumberOfWC',
#        'ConservationStatus', 'LivingArea', 'LotSize', 'BuiltArea',
#        'NumberOfBathrooms'],
#       dtype='object')

# %%
data_karakter = df.select_dtypes(include=['object'])
data_karakter.columns
# Out:
# Index([], dtype='object')

# %%
#sudah ditransform sebelumnya

# %%
df.head()
# Out:
#       Price  District  City    Town  Type  EnergyCertificate  Floor  Lift  \
# 0   55000.0         5    89   106.0    10                  9   18.0   0.0
# 1  289000.0        18   139   393.0     7                  5   18.0   0.0
# 2   46500.0        14   113   859.0    10                  9   18.0   2.0
# 3  203000.0        16   245  1825.0     0                  6    2.0   1.0
# 4   72500.0         2    52  1287.0    10                  9   18.0   2.0
#
#    Parking  HasParking  ...  Elevator  ElectricCarsCharging  TotalRooms  \
# 0      0.0         0.0  ...       2.0                   2.0         3.0
# 1      2.0         1.0  ...       2.0                   2.0         4.0
# 2      0.0         2.0  ...       0.0                   0.0         3.6
# 3      1.0         1.0  ...       2.0                   2.0         2.0
# 4      0.0         2.0  ...       0.0                   0.0         1.8
#
#    NumberOfBedrooms  NumberOfWC  ConservationStatus  LivingArea  LotSize  \
# ...

# %%
df.describe()
# Out:
#               Price      District          City          Town          Type  \
# count  1.975300e+04  19753.000000  19753.000000  19753.000000  19753.000000
# mean   3.609944e+05     11.553081    133.442110    897.013112      6.041462
# std    6.836709e+05      6.285493     73.453078    537.883892      5.252297
# min    1.000000e+02      0.000000      0.000000      0.000000      0.000000
# 25%    7.955100e+04      5.000000     74.000000    418.000000      0.000000
# 50%    1.999900e+05     14.000000    120.000000    902.000000      7.000000
# 75%    3.900000e+05     16.000000    204.000000   1370.000000     10.000000
# max    3.600000e+07     23.000000    263.000000   1869.000000     20.000000
#
#        EnergyCertificate        Floor          Lift       Parking  \
# count       19753.000000  19753.00000  19753.000000  19753.000000
# mean            6.286438     14.86802      0.965271      0.577016
# std             2.962139      6.17032      0.921212      0.880265
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.hist(figsize=(15, 18), bins=30,color='red');

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(data_numerik.corr(), annot=True, cmap='crest')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x=df['ElectricCarsCharging'], y=df['Garage'], color='green', alpha=0.5, s=10)
plt.title('Corelaton Fuel Consumption Combination & Fuel Consumption Highway')
plt.xlabel('Fuel Consumption Combination')
plt.ylabel('Fuel Consumption Highway')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x=df['ElectricCarsCharging'], y=df['Floor'], color='green', alpha=0.5, s=10)
plt.title('Corelaton Co2 & Fuel Consumption Mpg')
plt.xlabel('Fuel Consumption Combination mpg')
plt.ylabel('Fuel Consumption Combination')
plt.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(5, 5, figsize=(20, 20))
ax = ax.flatten()

for i, col in enumerate(df.columns):
    sns.boxplot(data=df, x=df[col], color='red', ax=ax[i])
    ax[i].set_title(col, fontsize=16)
    ax[i].set_xlabel('')

plt.tight_layout()
plt.show()

# %%
def iqr_outliers(data, col):
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    upper_bound = Q3 + 1.5 * IQR
    lower_bound = Q1 - 1.5 * IQR
    data[col] = data[col].mask(data[col] < lower_bound, Q1)
    data[col] = data[col].mask(data[col] > upper_bound, Q3)
    return data

for col in df.columns:
    iqr_outliers(df, col)

# %%
fig, ax = plt.subplots(5, 5, figsize=(15, 10))
ax = ax.flatten()

for i, col in enumerate(df.columns):
    sns.boxplot(data=df, x=df[col], color='red', ax=ax[i])
    ax[i].set_title(col, fontsize=16)
    ax[i].set_xlabel('')

plt.tight_layout()
plt.show()

# %%
x = df.drop('LotSize', axis=1)
y = df['LotSize']

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_scaled = pd.DataFrame(x_scaled, columns=x.columns)

# %%
x_scaled.head()
# Out:
#       Price  District      City      Town  Type  EnergyCertificate  Floor  \
# 0  0.064177  0.217391  0.338403  0.056715  0.50                0.9    0.0
# 1  0.337719  0.782609  0.528517  0.210273  0.35                0.5    0.0
# 2  0.054241  0.608696  0.429658  0.459604  0.50                0.9    0.0
# 3  0.237186  0.695652  0.931559  0.976458  0.00                0.6    0.0
# 4  0.084634  0.086957  0.197719  0.688604  0.50                0.9    0.0
#
#    Lift   Parking  HasParking  ...  Garage  Elevator  ElectricCarsCharging  \
# 0   0.0  0.000000         0.0  ...     1.0       1.0                   1.0
# 1   0.0  0.909091         0.5  ...     1.0       1.0                   1.0
# 2   1.0  0.000000         1.0  ...     0.0       0.0                   0.0
# 3   0.5  0.454545         0.5  ...     1.0       1.0                   1.0
# 4   1.0  0.000000         1.0  ...     0.0       0.0                   0.0
#
# ...

# %%
x_scaled.hist(figsize=(20, 20), bins=30,color='red');

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)

# %%
print(x_train.shape)
print(x_train.shape[0]/len(df)*100, '%')

print(x_test.shape)
print(x_test.shape[0]/len(df)*100, '%')
# Out:
# (15802, 24)
# 79.99797499114058 %
# (3951, 24)
# 20.002025008859412 %

# %%
x_train.head()
# Out:
#           Price  District      City      Town  Type  EnergyCertificate  Floor  \
# 6826   0.029108  0.217391  0.524715  0.087212  0.35                0.9    0.0
# 5771   0.619444  0.608696  0.228137  0.216693  0.00                0.4    0.0
# 9809   0.099247  0.130435  0.441065  0.468700  0.00                0.4    0.0
# 10375  0.003390  0.260870  0.832700  0.739968  0.50                0.9    0.0
# 2556   0.001637  0.739130  0.334601  0.094168  0.50                0.9    0.0
#
#        Lift   Parking  HasParking  ...  Garage  Elevator  \
# 6826    1.0  0.000000         1.0  ...     0.5       0.0
# 5771    0.5  0.454545         0.5  ...     1.0       1.0
# 9809    0.0  0.000000         0.0  ...     1.0       1.0
# 10375   0.0  0.000000         0.0  ...     1.0       1.0
# 2556    1.0  0.000000         1.0  ...     0.0       0.0
#
#        ElectricCarsCharging  TotalRooms  NumberOfBedrooms  NumberOfWC  \
# 6826                    0.0    0.555556          0.333333         0.0
# ...

# %%
y_train.head()
# Out:
# 6857       60.0
# 5792     5657.6
# 9875     1223.8
# 10452    2289.8
# 2561     2160.0
# Name: LotSize, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

model_linear = LinearRegression()

model_linear.fit(x_train, y_train)

y_pred_lr = model_linear.predict(x_test)

# %%
model_linear.intercept_
# Out:
# 2980.359837431312

# %%
linear_coef = pd.DataFrame({'Columns':x.columns, 'Coefficient':model_linear.coef_})
linear_coef
# Out:
#                  Columns   Coefficient
# 0                  Price  5.497118e+02
# 1               District -2.254809e+02
# 2                   City -1.153726e+02
# 3                   Town  2.959870e+02
# 4                   Type -5.480937e+01
# 5      EnergyCertificate  7.942714e+01
# 6                  Floor  4.547474e-13
# 7                   Lift  1.680813e+01
# 8                Parking  2.194659e+02
# 9             HasParking -2.899972e+02
# 10      ConstructionYear  1.320067e+01
# 11             TotalArea -3.948948e+02
# 12             GrossArea  3.239342e+02
# 13           PublishDate  1.136868e-13
# 14                Garage -2.293927e+02
# 15              Elevator  1.308279e+03
# 16  ElectricCarsCharging -2.629424e+02
# 17            TotalRooms -5.166959e+02
# 18      NumberOfBedrooms -5.134667e+02
# 19            NumberOfWC -5.684342e-14
# 20    ConservationStatus  0.000000e+00
# 21            LivingArea -5.127607e+00
# 22             BuiltArea  1.590542e+03
# ...

# %%
plt.figure(figsize=(20, 20))
plt.scatter(y_test, y_pred_lr, color='green', label='Test data', alpha=0.5, s=10)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', label='Garis linear', linestyle= '--')
plt.title('Linear Regression Model')
plt.xlabel('Actual Data')
plt.ylabel('Predicted Data')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score

mae_linear = mean_absolute_error(y_test, y_pred_lr)
mse_linear = mean_squared_error(y_test, y_pred_lr)
rms_linear = root_mean_squared_error(y_test, y_pred_lr)
r2_linear = r2_score(y_test, y_pred_lr)

print('mean absolute error:', mae_linear)
print('mean squared error:', mse_linear)
print('root mean squared error:', rms_linear)
print('r2 score:', r2_linear)
# Out:
# mean absolute error: 2076.029178385711
# mean squared error: 6579202.070404287
# root mean squared error: 2564.995530289339
# r2 score: 0.06122275450230974

# %%
error_values_lr = y_test - y_pred_lr

plt.figure(figsize=(8, 6))
plt.hist(error_values_lr, bins=50, density=True, color='blue', alpha=0.5)
plt.title('Error Values of Linear regression')
plt.xlabel('Error Values')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
from sklearn.linear_model import Ridge

model_ridge = Ridge(alpha=0.5)

model_ridge.fit(x_train, y_train)

y_pred_rd = model_ridge.predict(x_test)

# %%
model_ridge.intercept_
# Out:
# 2980.7259782188116

# %%
ridge_coef = pd.DataFrame({'Columns':x.columns, 'Coefficient':model_ridge.coef_})
ridge_coef
# Out:
#                  Columns  Coefficient
# 0                  Price   549.045055
# 1               District  -225.374425
# 2                   City  -115.284844
# 3                   Town   295.984699
# 4                   Type   -55.281557
# 5      EnergyCertificate    79.322358
# 6                  Floor     0.000000
# 7                   Lift    16.202874
# 8                Parking   219.215080
# 9             HasParking  -289.659673
# 10      ConstructionYear    13.420772
# 11             TotalArea  -392.960849
# 12             GrossArea   322.936966
# 13           PublishDate     0.000000
# 14                Garage  -229.155159
# 15              Elevator  1305.252820
# 16  ElectricCarsCharging  -260.513517
# 17            TotalRooms  -516.504585
# 18      NumberOfBedrooms  -513.422397
# 19            NumberOfWC     0.000000
# 20    ConservationStatus     0.000000
# 21            LivingArea    -5.166045
# 22             BuiltArea  1589.338472
# 23     NumberOfBathrooms  -562.684402

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred_rd, color='green', label='Test data', alpha=0.5, s=10)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', label='Garis linear', linestyle= '--')
plt.title('Ridge Regression Model')
plt.xlabel('Actual Data')
plt.ylabel('Predicted Data')
plt.legend()
plt.grid(True)
plt.show()

# %%
mae_ridge = mean_absolute_error(y_test, y_pred_rd)
mse_ridge = mean_squared_error(y_test, y_pred_rd)
rms_ridge = root_mean_squared_error(y_test, y_pred_rd)
r2_ridge = r2_score(y_test, y_pred_rd)

print('mean absolute error:', mae_ridge)
print('mean squared error:', mse_ridge)
print('root mean squared error:', rms_ridge)
print('r2 score:', r2_ridge)
# Out:
# mean absolute error: 2076.0339900981007
# mean squared error: 6579079.376828452
# root mean squared error: 2564.9716132597746
# r2 score: 0.061240261478981206

# %%
error_values_rd = y_test - y_pred_rd

plt.figure(figsize=(8, 6))
plt.hist(error_values_rd, bins=50, density=True, color='blue', alpha=0.5)
plt.title('Error Values of Ridge Regression')
plt.xlabel('Error Values')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
from sklearn.linear_model import Lasso

model_lasso = Lasso(alpha=0.5)

model_lasso.fit(x_train, y_train)

y_pred_ls = model_lasso.predict(x_test)

# %%
model_lasso.intercept_
# Out:
# 2935.0536295424413

# %%
lasso_coef = pd.DataFrame({'Columns':x.columns, 'Coefficient':model_lasso.coef_})
lasso_coef
# Out:
#                  Columns  Coefficient
# 0                  Price   529.883064
# 1               District  -218.311690
# 2                   City  -107.049775
# 3                   Town   288.586468
# 4                   Type   -51.325011
# 5      EnergyCertificate    67.784155
# 6                  Floor     0.000000
# 7                   Lift     0.000000
# 8                Parking   176.800359
# 9             HasParking  -221.291220
# 10      ConstructionYear     4.452461
# 11             TotalArea  -336.469950
# 12             GrossArea   275.434278
# 13           PublishDate     0.000000
# 14                Garage  -224.479994
# 15              Elevator  1272.110135
# 16  ElectricCarsCharging  -187.066493
# 17            TotalRooms  -511.543603
# 18      NumberOfBedrooms  -502.809971
# 19            NumberOfWC     0.000000
# 20    ConservationStatus     0.000000
# 21            LivingArea    -0.000000
# 22             BuiltArea  1577.662573
# 23     NumberOfBathrooms  -553.910814

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred_ls, color='green', label='Test data', alpha=0.5, s=10)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', label='Garis linear', linestyle= '--')
plt.title('Lasso Regression Model')
plt.xlabel('Actual Data')
plt.ylabel('Predicted Data')
plt.legend()
plt.grid(True)
plt.show()

# %%
mae_lasso = mean_absolute_error(y_test, y_pred_ls)
mse_lasso = mean_squared_error(y_test, y_pred_ls)
rms_lasso = root_mean_squared_error(y_test, y_pred_ls)
r2_lasso = r2_score(y_test, y_pred_ls)

print('mean absolute error:', mae_lasso)
print('mean squared error:', mse_lasso)
print('root mean squared error:', rms_lasso)
print('r2 score:', r2_lasso)
# Out:
# mean absolute error: 2076.2743895595227
# mean squared error: 6577010.081137139
# root mean squared error: 2564.5682055927346
# r2 score: 0.06153552641968718

# %%
error_values_ls = y_test - y_pred_ls

plt.figure(figsize=(8, 6))
plt.hist(error_values_ls, bins=50, density=True, color='blue', alpha=0.5)
plt.title('Error Values of Lasso Regression')
plt.xlabel('Error Values')
plt.ylabel('Density')
plt.grid(True)
plt.show()
